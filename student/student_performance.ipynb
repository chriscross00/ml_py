# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('student-mat.csv', sep=';')

df.shape
# Out:
# (395, 33)

# %% [markdown]
# Getting a general sense of the data

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %% [markdown]
# Checking the data types for each column and checking for NaNs.

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  reason guardian  traveltime   studytime  \
# count   395.000000    395    395     395      395  395.000000  395.000000
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# Male vs Female for the final grade.

# %%
plt.figure(figsize=(6,6))
sns.boxplot('sex', 'G3', data=df)

# %% [markdown]
# Students that paid for extra classes outside of school have tighter extremes and 1st and 3rd quantiles. Students that paid and students that did not pay for had the same G3 median, though students that paid for classes had a higher expected G3 score by almost 1, 0.9367

# %%
plt.figure(figsize=(6,6))
sns.boxplot('paid', 'G3', data=df)
plt.ylabel('G3 Score')
# Out:
# Text(0, 0.5, 'G3 Score')

# %%
df.groupby(['paid']).median()
df.groupby(['paid']).mean()
# Out:
#             age      Medu      Fedu  traveltime  studytime  failures  \
# paid
# no    16.738318  2.588785  2.434579    1.490654   1.906542  0.462617
# yes   16.646409  2.939227  2.624309    1.397790   2.187845  0.182320
#
#         famrel  freetime     goout      Dalc      Walc    health  absences  \
# paid
# no    3.943925  3.294393  3.098131  1.429907  2.219626  3.654206  5.654206
# yes   3.944751  3.165746  3.121547  1.541436  2.375691  3.436464  5.773481
#
#              G1         G2         G3
# paid
# no    10.789720  10.350467   9.985981
# yes   11.049724  11.143646  10.922652
